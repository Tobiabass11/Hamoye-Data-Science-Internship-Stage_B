# %% [markdown]
# ## Abass-Alesinloye Stage_B Graded Quiz
# ## Hamoye ID:  146eb423f281f000

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import  mean_squared_error
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# %%
dataframe= pd.read_csv('energydata_complete.csv', encoding='latin-1')
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %% [markdown]
# Removing Dates and Lights

# %%
dataframe =dataframe.drop(columns=['date', 'lights'])
df.head()
# Out:
#    Appliances     T1       RH_1    T2       RH_2     T3       RH_3         T4  \
# 0          60  19.89  47.596667  19.2  44.790000  19.79  44.730000  19.000000
# 1          60  19.89  46.693333  19.2  44.722500  19.79  44.790000  19.000000
# 2          50  19.89  46.300000  19.2  44.626667  19.79  44.933333  18.926667
# 3          50  19.89  46.066667  19.2  44.590000  19.79  45.000000  18.890000
# 4          60  19.89  46.333333  19.2  44.530000  19.79  45.000000  18.890000
#
#         RH_4         T5  ...         T9   RH_9     T_out  Press_mm_hg  RH_out  \
# 0  45.566667  17.166667  ...  17.033333  45.53  6.600000        733.5    92.0
# 1  45.992500  17.166667  ...  17.066667  45.56  6.483333        733.6    92.0
# 2  45.890000  17.166667  ...  17.000000  45.50  6.366667        733.7    92.0
# 3  45.723333  17.166667  ...  17.000000  45.40  6.250000        733.8    92.0
# 4  45.530000  17.200000  ...  17.000000  45.40  6.133333        733.9    92.0
#
# ...

# %% [markdown]
# Scaling with MinMaxScaler

# %%
#Loading the dataset as a normalized DataFrame with columns as columns of dataset

scaler = MinMaxScaler()
scaled_df = pd.DataFrame(scaler.fit_transform(dataframe), columns = dataframe.columns)

# %% [markdown]
# To get features

# %%
features_df=scaled_df.drop(columns=['Appliances'])
features_df.head()
# Out:
#         T1      RH_1        T2      RH_2        T3      RH_3        T4  \
# 0  0.32735  0.566187  0.225345  0.684038  0.215188  0.746066  0.351351
# 1  0.32735  0.541326  0.225345  0.682140  0.215188  0.748871  0.351351
# 2  0.32735  0.530502  0.225345  0.679445  0.215188  0.755569  0.344745
# 3  0.32735  0.524080  0.225345  0.678414  0.215188  0.758685  0.341441
# 4  0.32735  0.531419  0.225345  0.676727  0.215188  0.758685  0.341441
#
#        RH_4        T5      RH_5  ...        T9      RH_9     T_out  \
# 0  0.764262  0.175506  0.381691  ...  0.223032  0.677290  0.372990
# 1  0.782437  0.175506  0.381691  ...  0.226500  0.678532  0.369239
# 2  0.778062  0.175506  0.380037  ...  0.219563  0.676049  0.365488
# 3  0.770949  0.175506  0.380037  ...  0.219563  0.671909  0.361736
# 4  0.762697  0.178691  0.380037  ...  0.219563  0.671909  0.357985
#
#    Press_mm_hg    RH_out  Windspeed  Visibility  Tdewpoint       rv1       rv2
# ...

# %% [markdown]
# To get target

# %%
response_df=scaled_df['Appliances']
response_df.head()
# Out:
# 0    0.046729
# 1    0.046729
# 2    0.037383
# 3    0.037383
# 4    0.046729
# Name: Appliances, dtype: float64

# %% [markdown]
# ### For R-Squared for x=T2 and y=T6

# %% [markdown]
# Obtaining Sample of required data

# %%
sample = scaled_df[['T2', 'T6']]
sample.head()
# Out:
#          T2        T6
# 0  0.225345  0.381070
# 1  0.225345  0.375443
# 2  0.225345  0.367487
# 3  0.225345  0.363800
# 4  0.225345  0.361859

# %% [markdown]
# To reshape sample and assign to x and y

# %%
x = sample['T2'].values.reshape(-1,1)
y = sample['T6'].values.reshape(-1,1)

# %% [markdown]
# Splitting reshaped data into train and test sets

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# Finding R-Squared for sample model

# %%
sample_model = LinearRegression()

sample_model.fit(xtrain, ytrain)

sample_pred_vals = sample_linear_model.predict(xtest)


r2_score = r2_score(ytest, sample_pred_vals)

print('R-squared =',(round(r2_score, 2)), 'to 2dp')
# Out:
# R-squared = 0.64 to 2dp

# %% [markdown]
# ### For to Main Data

# %% [markdown]
# Splitting data into train and test sets

# %%
x_train, x_test, y_train, y_test = train_test_split(features_df, response_df, test_size = 0.3, random_state = 42)

# %% [markdown]
# Calling the linear Regression model

# %%
linear_model = LinearRegression()

# %% [markdown]
# Fitting the model to the training data

# %%
linear_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Obtaining predictions

# %%
predicted_values = linear_model.predict(x_test)

# %% [markdown]
# FInding Mean Absolute Error (MAE)

# %%
mae = mean_absolute_error(y_test, predicted_values)

print('MAE =',(round(mae, 2)), 'to 2dp')
# Out:
# MAE = 0.05 to 2dp

# %% [markdown]
# Finding Residual Sum of Squares (RSS)

# %%
rss = np.sum(np.square(y_test - predicted_values))
print('RSS = ',(round(rss, 2)), 'to 2dp')
# Out:
# RSS =  45.35 to 2dp

# %% [markdown]
# FInding Root Mean Squared Error (RMSE)

# %%
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
print('RMSE = ',(round(rmse, 3)), 'to 3dp')
# Out:
# RMSE =  0.088 to 3dp

# %% [markdown]
# Finding Coefficient of Determination or R-Squared

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y_test, predicted_values)
print('R-squared = ',(round(r2_score, 2)), 'to 2dp')
# Out:
# R-squared =  0.15 to 2dp

# %% [markdown]
# Finding Lowest and Highest Feature Weights of Linear Model

# %%
#To obtain the weight of every feature as a dataframe per model using the function below
def for_weights_df(model, features_df, column_name):
    weights= pd.Series(model.coef_, index=features_df.columns)
    weights= pd.Series(model.coef_, index=features_df.columns).sort_values()
    weights_df=pd.DataFrame(weights).reset_index()
    weights_df.columns=['Features', column_name]
    return weights_df
#Calling weight function on linear_model
linear_model_weights_df = for_weights_df(linear_model, x_train, 'Linear_Model_Weight')
print(f"The Feature with the Lowest weight is {linear_model_weights_df.at[0,'Features']}")
print(f"The Feature with the Highest weight is {linear_model_weights_df.at[25,'Features']}")
linear_model_weights_df
# Out:
# The Feature with the Lowest weight is RH_2
# The Feature with the Highest weight is RH_1
#        Features  Linear_Model_Weight
# 0          RH_2            -0.456698
# 1         T_out            -0.321860
# 2            T2            -0.236178
# 3            T9            -0.189941
# 4          RH_8            -0.157595
# 5        RH_out            -0.077671
# 6          RH_7            -0.044614
# 7          RH_9            -0.039800
# 8            T5            -0.015657
# 9            T1            -0.003281
# 10          rv1             0.000770
# 11          rv2             0.000770
# 12  Press_mm_hg             0.006839
# 13           T7             0.010319
# 14   Visibility             0.012307
# 15         RH_5             0.016006
# 16         RH_4             0.026386
# 17           T4             0.028981
# 18    Windspeed             0.029183
# 19         RH_6             0.038049
# 20         RH_3             0.096048
# 21           T8             0.101995
# ...

# %% [markdown]
# Performing RMSE on Ridge Regression having alpha value of 0.4

# %%
ridge_reg = Ridge(alpha=0.4)

ridge_reg.fit(x_train, y_train)

ridge_pred = ridge_reg.predict(x_test)

rmse = np.sqrt(mean_squared_error(y_test, ridge_pred))

print('RMSE = ',(round(rmse, 3)), 'to 3dp')
print('No Change in RMSE Value as it remains same')
# Out:
# RMSE =  0.088 to 3dp
# No Change to RMSE Value

# %% [markdown]
# Lasso Regression with alpha value of 0.001

# %%
lasso_reg = Lasso(alpha=0.001)

lasso_reg.fit(x_train, y_train)

lasso_pred = lasso_reg.predict(x_test)

lasso_weights_df = for_weights_df(lasso_reg, x_train, 'Lasso_Weight')

print('4 non-zero feature weights which are: RH_out, RH_8, Windspeed, RH_1')

lasso_weights_df
# Out:
# 4 Features have non-zero feature weights: RH_out, RH_8, Windspeed, RH_1
#        Features  Lasso_Weight
# 0        RH_out     -0.049557
# 1          RH_8     -0.000110
# 2            T1      0.000000
# 3     Tdewpoint      0.000000
# 4    Visibility      0.000000
# 5   Press_mm_hg     -0.000000
# 6         T_out      0.000000
# 7          RH_9     -0.000000
# 8            T9     -0.000000
# 9            T8      0.000000
# 10         RH_7     -0.000000
# 11          rv1     -0.000000
# 12           T7     -0.000000
# 13           T6      0.000000
# 14         RH_5      0.000000
# 15           T5     -0.000000
# 16         RH_4      0.000000
# 17           T4     -0.000000
# 18         RH_3      0.000000
# 19           T3      0.000000
# 20         RH_2     -0.000000
# 21           T2      0.000000
# 22         RH_6     -0.000000
# 23          rv2     -0.000000
# 24    Windspeed      0.002912
# 25         RH_1      0.017880

# %% [markdown]
# New RMSE with Lasso Regression to 3dp

# %%
rmse = np.sqrt(mean_squared_error(y_test, lasso_pred))

print('RMSE = ',(round(rmse, 3)), 'to 3dp')
# Out:
# RMSE =  0.094 to 3dp
